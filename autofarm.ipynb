# %% [markdown]
# # Welcome to programatically playing CafeCosmos

# %%
#These are imports, configs, and the world object

from cafecosmos import World, Player

network = "mainnet"

abi_dir = "./cafecosmos-contracts/abi"
mud_config_path = "./cafecosmos-contracts/mud.config.ts"
rpc = "https://rpc.redstonechain.com"
indexer_url = "https://indexer.mud.redstonechain.com/q"
block_explorer_url = "https://explorer.redstone.xyz"

#The world address (and landId) can be found in the in-game settings
world_address = "0xBA24a3E1980D25E3A23A0d62dDA9a49917D811D6"

cafecosmos = World(rpc, 
              world_address, 
              abi_dir, 
              indexer_url=indexer_url, 
              mud_config_path=mud_config_path,
              block_explorer_url=block_explorer_url)
# Out:
# /Users/nico/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Importing your Player
#
# To make a player create a .env file in this directory.
#
# 1. In CafeCosmos go to your wallet and copy your private key
#
#     ![Backup your private key](./img/backup.png)
#
# 2. Then in your terminal execute this code to setup your .env file!
#
#     ```bash
#     touch .env #creates the environment file
#     echo PLAYER1=YOUR_PRIVATE_KEY >> .env #writes your pk
#     ```
#
#     Replace YOUR_PRIVATE_KEY with your actual private key.

# %%
#if you don't know your land_id leave it empty
player = Player(env_key_name="PLAYER1", world=cafecosmos)
print(player.land_id)
# Out:
# 2

# %% [markdown]
# # The Player class
#
# with Player, you can do a variety of things like
#
# `player.displayInventory()` Displays the inventory
#
# `player.unlock_all()` Unlocks all the unlockable
#
# `player.placeItem(x, y, "item name")` Places an item down at that exact location
#
# `player.placeItem(x, y, "unlock")` Unlocks the item at that location
#
# `player.auto_farm()` unlocks every item when it's ready automatically

# %% [markdown]
# ## This is the display land function
#
# It will display your land in a nice way.
#
# *You can hover over items to see their exact coordinate and numerical itemId*

# %%
player.display_land()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>x</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#     <tr>
#       <th>y</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/bismuth.png" title="Name: Bismuth | Item ID: 19.0 | Coordinates: (4, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (7, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (9, 0)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (1, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Unknown | Coordinates: (3, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/planet_sign.png" title="Name: Wall With Planet Sign | Item ID: 100.0 | Coordinates: (4, 1)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (8, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (9, 1)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (1, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (2, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/bar_table.png" title="Name: Unknown | Coordinates: (3, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 2)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (0, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/plant.png" title="Name: Plant | Item ID: 95.0 | Coordinates: (1, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_machine.png" title="Name: Unknown | Coordinates: (3, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 3)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (9, 3)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_window.png" title="Name: Wall With Window | Item ID: 101.0 | Coordinates: (1, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_menu.png" title="Name: Wall With Menu | Item ID: 102.0 | Coordinates: (2, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Unknown | Coordinates: (3, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (4, 4)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 5)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (6, 5)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (8, 5)" width="50"/></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Unknown | Coordinates: (3, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/raspberry_bush.png" title="Name: Raspberry Bush | Item ID: 56.0 | Coordinates: (4, 6)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/chicken.png" title="Name: Chicken | Item ID: 104.0 | Coordinates: (7, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/cow.png" title="Name: Cow | Item ID: 103.0 | Coordinates: (8, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (9, 6)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/sugar_tree.png" title="Name: Sugar Tree | Item ID: 63.0 | Coordinates: (1, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/simple_tree.png" title="Name: Unknown | Coordinates: (3, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (7, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Unknown | Coordinates: (3, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (9, 8)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="./cafecosmos-contracts/icons/avocado_tree.png" title="Name: Avocado Tree | Item ID: 60.0 | Coordinates: (0, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (1, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (2, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Unknown | Coordinates: (3, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (4, 9)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana

# %% [markdown]
# ## This is the display inventory function
#
# It will display your inventory.

# %%
player.display_inventory()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Icon</th>
#       <th>Item Name</th>
#       <th>Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/axe.png" title="Unknown Item" width="50"/></td>
#       <td>Axe</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/pickaxe.png" title="Unknown Item" width="50"/></td>
#       <td>Pickaxe</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/green_chair.png" title="Unknown Item" width="50"/></td>
#       <td>Green Chair</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/hoe.png" title="Unknown Item" width="50"/></td>
#       <td>Hoe</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/scythe.png" title="Unknown Item" width="50"/></td>
#       <td>Scythe</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/watering_can_full.png" title="Unknown Item" width="50"/></td>
#       <td>Watering Can Full</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/green_table.png" title="Unknown Item" width="50"/></td>
#       <td>Green Table</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/coffee.png" title="Unknown Item" width="50"/></td>
#       <td>Coffee</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Unknown Item" width="50"/></td>
#       <td>Clay</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/crystal.png" title="Unknown Item" width="50"/></td>
#       <td>Crystal</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/sticks.png" title="Unknown Item" width="50"/></td>
#       <td>Sticks</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/avocado.png" title="Unknown Item" width="50"/></td>
#       <td>Avocado</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/sugar.png" title="Unknown Item" width="50"/></td>
#       <td>Sugar</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/raspberry.png" title="Unknown Item" width="50"/></td>
#       <td>Raspberry</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bean.png" title="Unknown Item" width="50"/></td>
#       <td>Coffee Bean</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/olives.png" title="Unknown Item" width="50"/></td>
#       <td>Olives</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/bananas.png" title="Unknown Item" width="50"/></td>
#       <td>Bananas</td>
#       <td>108</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/egg.png" title="Unknown Item" width="50"/></td>
#       <td>Egg</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <td><img src="./cafecosmos-contracts/icons/bismuth.png" title="Unknown Item" width="50"/></td>
#       <td>Bismuth</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Unlock all
#
# It unlocks everything that can be unlocked! It harvests all your fruit trees for example at once!

# %%
player.unlock_all()
player.display_land()
# Out:
# Transaction sent: https://explorer.redstone.xyz/tx/0xdacc7ed312ece5c49c74d56a23822d02518e008b99bc3ebcf77c7caf61be3df9
# Transaction confirmed in block: 12181603
# Unlocked item at coordinates (0, 9)
# Transaction sent: https://explorer.redstone.xyz/tx/0x40fe2e96bfdaf3377631cca50a7602f0f2581d998e500a7dddf90f5e1e53873b
# Transaction confirmed in block: 12181605
# Unlocked item at coordinates (0, 3)
# Transaction sent: https://explorer.redstone.xyz/tx/0xe944c6be7a2d9f50326d7bb118a87503cad779eacc0b71ed2945bda824d987c1
# Transaction confirmed in block: 12181607
# Unlocked item at coordinates (1, 7)
# Transaction sent: https://explorer.redstone.xyz/tx/0x86497015143d37b989cb57eee7a2269d36e358c8177362363d6f7a9e5f3b08f3
# Transaction confirmed in block: 12181609
# Unlocked item at coordinates (3, 6)
# Transaction sent: https://explorer.redstone.xyz/tx/0xa19d3e8a0820b7c65a41d3b7865f2ccdfdaf38183f1b0870cfd3fdfacfab2789
# Transaction confirmed in block: 12181611
# Unlocked item at coordinates (4, 6)
# Transaction sent: https://explorer.redstone.xyz/tx/0x8964ed4d9592dd3fe53ffa0dd69ba13de52bddb8644466b43e90c538c6735306
# Transaction confirmed in block: 12181613
# Unlocked item at coordinates (4, 4)
# Transaction sent: https://explorer.redstone.xyz/tx/0x2a370c4af31bf68e9a20b6ab6540d770879b019cf2226149423077a80a612201
# Transaction confirmed in block: 12181615
# Unlocked item at coordinates (1, 9)
# Transaction sent: https://explorer.redstone.xyz/tx/0x46f1db82c834cdc485d75afda5a1931bd6e22366b43a3882dad99d0526aeb553
# Transaction confirmed in block: 12181617
# Unlocked item at coordinates (7, 7)
# Transaction sent: https://explorer.redstone.xyz/tx/0xc2ce0c28c5add66bdabc8f128d48786df59d9425ead32ff59371f1bb9d68e1dc
# Transaction confirmed in block: 12181619
# Unlocked item at coordinates (9, 8)
# Transaction sent: https://explorer.redstone.xyz/tx/0x2977d0d9e22a6dd55f44374d3c67e9f2cce525b6d12c5e8316c324a8448d40d3
# Transaction confirmed in block: 12181621
# Unlocked item at coordinates (8, 1)
# Transaction sent: https://explorer.redstone.xyz/tx/0xbd1311898cdc81b145a95409b7f6d66759ef16ea7ac5dc014f5270553178f07e
# Transaction confirmed in block: 12181623
# Unlocked item at coordinates (9, 0)
# Transaction sent: https://explorer.redstone.xyz/tx/0x4b1a1364e2d09befd449921cadbc0893aec3225086e85cb64fc93ed8f40a12e1
# Transaction confirmed in block: 12181625
# Unlocked item at coordinates (6, 9)
# Transaction sent: https://explorer.redstone.xyz/tx/0x5cf5144be0792021e9737d7b90ca4cfaa0b2e47c440ea2106e9369c2602fa559
# Transaction confirmed in block: 12181627
# Unlocked item at coordinates (7, 6)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>x</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#     <tr>
#       <th>y</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/bismuth.png" title="Name: Bismuth | Item ID: 19.0 | Coordinates: (4, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (7, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (9, 0)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (1, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Unknown | Coordinates: (3, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/planet_sign.png" title="Name: Wall With Planet Sign | Item ID: 100.0 | Coordinates: (4, 1)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (8, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (9, 1)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (1, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (2, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/bar_table.png" title="Name: Unknown | Coordinates: (3, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 2)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (0, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/plant.png" title="Name: Plant | Item ID: 95.0 | Coordinates: (1, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_machine.png" title="Name: Unknown | Coordinates: (3, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 3)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (9, 3)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_window.png" title="Name: Wall With Window | Item ID: 101.0 | Coordinates: (1, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_menu.png" title="Name: Wall With Menu | Item ID: 102.0 | Coordinates: (2, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Unknown | Coordinates: (3, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (4, 4)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 5)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (6, 5)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (8, 5)" width="50"/></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Unknown | Coordinates: (3, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/raspberry_bush.png" title="Name: Raspberry Bush | Item ID: 56.0 | Coordinates: (4, 6)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/chicken.png" title="Name: Chicken | Item ID: 104.0 | Coordinates: (7, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/cow.png" title="Name: Cow | Item ID: 103.0 | Coordinates: (8, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (9, 6)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/sugar_tree.png" title="Name: Sugar Tree | Item ID: 63.0 | Coordinates: (1, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/simple_tree.png" title="Name: Unknown | Coordinates: (3, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (7, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Unknown | Coordinates: (3, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (9, 8)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="./cafecosmos-contracts/icons/avocado_tree.png" title="Name: Avocado Tree | Item ID: 60.0 | Coordinates: (0, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (1, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (2, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Unknown | Coordinates: (3, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (4, 9)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana

# %% [markdown]
# # Crafting

# %% [markdown]
# Let's craft a furnace!

# %%
player.craft_item("furnace")
# Out:
# Transaction sent: https://explorer.redstone.xyz/tx/0x655705cbcc59bd9f3ca34d26f973b6e50f39478adb6120daa9c03ef0a1e17098
# Transaction confirmed in block: 12181719

# %% [markdown]
# Let's place down the furnace

# %%
player.place_item(5,1,"furnace")
# Out:
# Transaction sent: https://explorer.redstone.xyz/tx/0x62db9cd149bf3bc667a8eaa34c4c18d457ea48fdfcd1f50cff4c50be16dabb74
# Transaction confirmed in block: 12181724

# %% [markdown]
# Let's smelt bismuth by placing it on top of the furnace

# %%
player.place_item(5,1,"bismuth")
# Out:
# Transaction sent: https://explorer.redstone.xyz/tx/0xa1b5fa4fc65ff5a4273d39d2e0fc8af41e5171b0b9c0f712e48e289a7c0b2c92
# Transaction confirmed in block: 12182436

# %% [markdown]
# Let's see how our land is doing!

# %%
player.display_land()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>x</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#     <tr>
#       <th>y</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/bismuth.png" title="Name: Bismuth | Item ID: 19.0 | Coordinates: (4, 0)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/bismuth.png" title="Name: Bismuth | Item ID: 19.0 | Coordinates: (5, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (7, 0)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (9, 0)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (1, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Unknown | Coordinates: (3, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/planet_sign.png" title="Name: Wall With Planet Sign | Item ID: 100.0 | Coordinates: (4, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/furnace_smelting_bismuth.png" title="Name: Furnace Smelting Bismuth | Item ID: 77.0 | Coordinates: (5, 1)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (8, 1)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (9, 1)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (1, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/pink_floor.png" title="Name: Pink Floor | Item ID: 97.0 | Coordinates: (2, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/bar_table.png" title="Name: Unknown | Coordinates: (3, 2)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 2)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (0, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/plant.png" title="Name: Plant | Item ID: 95.0 | Coordinates: (1, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/purple_floor.png" title="Name: Purple Floor | Item ID: 98.0 | Coordinates: (2, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_machine.png" title="Name: Unknown | Coordinates: (3, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Wall | Item ID: 99.0 | Coordinates: (4, 3)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 3)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/tomato.png" title="Name: Grass Tomato | Item ID: 113.0 | Coordinates: (9, 3)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_window.png" title="Name: Wall With Window | Item ID: 101.0 | Coordinates: (1, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall_with_menu.png" title="Name: Wall With Menu | Item ID: 102.0 | Coordinates: (2, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/wall.png" title="Name: Unknown | Coordinates: (3, 4)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/coffee_bush.png" title="Name: Coffee Bush | Item ID: 57.0 | Coordinates: (4, 4)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 5)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (6, 5)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Grass Wheat | Item ID: 114.0 | Coordinates: (8, 5)" width="50"/></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Unknown | Coordinates: (3, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/raspberry_bush.png" title="Name: Raspberry Bush | Item ID: 56.0 | Coordinates: (4, 6)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/chicken.png" title="Name: Chicken | Item ID: 104.0 | Coordinates: (7, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/cow.png" title="Name: Cow | Item ID: 103.0 | Coordinates: (8, 6)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/grass.png" title="Name: Grass Lettuce | Item ID: 55.0 | Coordinates: (9, 6)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/sugar_tree.png" title="Name: Sugar Tree | Item ID: 63.0 | Coordinates: (1, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/simple_tree.png" title="Name: Unknown | Coordinates: (3, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (7, 7)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/wheat.png" title="Name: Unknown | Coordinates: (3, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (5, 8)" width="50"/></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td><img src="./cafecosmos-contracts/icons/olive_tree.png" title="Name: Olive Tree | Item ID: 62.0 | Coordinates: (9, 8)" width="50"/></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="./cafecosmos-contracts/icons/avocado_tree.png" title="Name: Avocado Tree | Item ID: 60.0 | Coordinates: (0, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/banana_tree.png" title="Name: Banana Tree | Item ID: 61.0 | Coordinates: (1, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Clay | Item ID: 22.0 | Coordinates: (2, 9)" width="50"/></td>
#       <td><img src="./cafecosmos-contracts/icons/clay.png" title="Name: Unknown | Coordinates

# %% [markdown]
# Notice the furnace cooking?
#
# Let's check how much longer until it's ready

# %%
import time

time_to_unlock = player.time_until_unlock(5, 1)
print("time to unlock", time_to_unlock)

time.sleep(time_to_unlock) # Let's wait until it's ready
# Out:
# time to unlock 0

# %% [markdown]
# Now let's collect the bismuth

# %%
player.place_item(5, 1, "unlock")
# Out:
# Transaction sent: https://explorer.redstone.xyz/tx/0x373ee027e942905bcb2dc1d5a23920f34b5a3bc8237d16cabcfc5f8c37562680
# Transaction confirmed in block: 12182485

# %% [markdown]
# We can see what we can craft with our current inventory with `player.get_craftable()`

# %%
player.get_craftable()
# Out:
#     Item ID          Item Name  Max Craftable                    Requirements
# 0         5             Coffee             71                 1 x Coffee Bean
# 1       987            Furnace              2        5 x Crystal, 3 x Bismuth
# 2        29              Blade              2        4 x Bismuth, 1 x Crystal
# 3       111                Axe             12         3 x Crystal, 2 x Sticks
# 4       110            Pickaxe             12         3 x Crystal, 2 x Sticks
# 5        28               Wire              8  1 x Bismuth Ingot, 1 x Bismuth
# 6        27              Glass             67                     1 x Crystal
# 7       112                Hoe             12         2 x Crystal, 2 x Sticks
# 8       108             Scythe             12         2 x Crystal, 2 x Sticks
# 9      1010  Watering Can Full             22                     3 x Crystal
# 10     1007               Pole              8                      3 x Sticks

# %% [markdown]
# # Auto Farm
#
# Let's start autofarming our trees!  🌳

# %%
player.auto_farm()
# Out:
# Unlocking 13 items...
# Transaction sent: https://explorer.redstone.xyz/tx/0xbfda0088d08edc62255cb6bff8adb3bcf7bd80887aea990ab3b28b4e142dacd6
# Transaction confirmed in block: 12182651
# Unlocked item at coordinates (0, 9)
# Transaction sent: https://explorer.redstone.xyz/tx/0xf2a92bfde3039a510e664785b00b4b5ad961b603678d24c1cd2b80f3acb1102d
# Transaction confirmed in block: 12182653
# Unlocked item at coordinates (0, 3)
# Transaction sent: https://explorer.redstone.xyz/tx/0xda5ba37bfd40fb2867f6ded80655179480eacba1f5eb35dc2990c8a6a73198df
# Transaction confirmed in block: 12182655
# Unlocked item at coordinates (1, 7)
# Transaction sent: https://explorer.redstone.xyz/tx/0x919b22e6844602aa9b5ab7bb794c362c6a3ef1ddad4a8651724b7bd82eaff66f
# Transaction confirmed in block: 12182657
# Unlocked item at coordinates (3, 6)
# Transaction sent: https://explorer.redstone.xyz/tx/0xce0966a3a540e39d91639dd55afceba36acfdecaa23f1374a7bc12d5cbdac37d
# Transaction confirmed in block: 12182659
# Unlocked item at coordinates (4, 6)
# Transaction sent: https://explorer.redstone.xyz/tx/0x708be08457ce391b0866766747e453bf4f5949e9e0a0c561d50974a3afab5b59
# Transaction confirmed in block: 12182661
# Unlocked item at coordinates (4, 4)
# Transaction sent: https://explorer.redstone.xyz/tx/0x97bb96a3e06162f2382d7a8f3e3891dd3a9bf802480ff4b90c4c69b370ce2991
# Transaction confirmed in block: 12182663
# Unlocked item at coordinates (1, 9)
# Transaction sent: https://explorer.redstone.xyz/tx/0x2571a5f07d26b04829de0184d489899e7370b6a10619a1dce745488542712737
# Transaction confirmed in block: 12182665
# Unlocked item at coordinates (7, 7)
# Transaction sent: https://explorer.redstone.xyz/tx/0xa0a5b82fbbb617e539498ab340480b0cd9c4565d4972d9cac72ab2b73fba3b5f
# Transaction confirmed in block: 12182667
# Unlocked item at coordinates (9, 8)
# Transaction sent: https://explorer.redstone.xyz/tx/0xb3cfbd00b03db728adf2b7ef69c6f654eb5102b4285511237c8580fb87cef774
# Transaction confirmed in block: 12182669
# Unlocked item at coordinates (8, 1)
# Transaction sent: https://explorer.redstone.xyz/tx/0x8163acc7bbb5284a703fc8736681e9fbaa066e03665fcca500dbca70c06bc6ba
# Transaction confirmed in block: 12182671
# Unlocked item at coordinates (9, 0)
# Transaction sent: https://explorer.redstone.xyz/tx/0x1d7941e2bdf7c6654a4e9d6767c50354799be000e20f77bf5bebfcf4a9910742
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 player.auto_farm()
#
# File ~/Workspace/cafecosmos-sdk/cafecosmos.py:288, in auto_farm(self)
#     286 unlock_data = self.get_unlockable_transformations()
#     287 coordinates = unlock_data['coordinates']
# --> 288 failed_items = []
#     290 for coord in coordinates:
#     291     try:
#     292         # Ensure a recheck of the unlock condition before unlocking
#
# File ~/Workspace/cafecosmos-sdk/cafecosmos.py:271, in unlock_all(self)
#     268 placementtime = int(item.get('placementtime', 0))
#     269 total_unlock_time = unlocktime + placementtime
# --> 271 # Adjust unlock logic to add a safety margin
#     272 if total_unlock_time <= timestamp:
#     273     # Add to unlockable coordinates
#     274     coordinates.append((int(item['x']), int(item['y'])))
#
# File ~/Workspace/cafecosmos-sdk/cafecosmos.py:89, in Player.place_item(self, x, y, item_name)
#      86 else:
#      87     item_id=name_to_id_fuzzy(item_name)
# ---> 89 place_item(self, self.land_id, x, y, item_id)
#
# File ~/Workspace/cafecosmos-sdk/cafecosmos.py:611, in place_item(player, land_id, x, y, item_id, display)
#     609 # Call the placeItem function in the World contract
#     610 function_call = player.cafecosmos.placeItem(land_id, x, y, item_id, mode="raw")
# --> 611 _execute_function_call(player=player, function_call=function_call)
#     612 if(display):
#     613     display_land(player.cafecosmos, land_id)
#
# File ~/Workspace/cafecosmos-sdk/cafecosmos.py:585, in _execute_function_call(player, function_call)
#     582 # Constants
#     583 RESOURCE_SYSTEM = Web3.keccak(text="system")[:16]
# --> 585 # Encode namespace and system name
#     586 namespace_bytes = b"".ljust(14, b'\0')  # Empty namespace, 14 bytes
#     587 system_name_bytes = system_name.encode('utf-8')[:16].ljust(16, b'\0')  # System name, 16 bytes
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/eth/eth.py:487, in Eth.wait_for_transaction_receipt(self, transaction_hash, timeout, poll_latency)
#     485 while True:
#     486     try:
# --> 487         tx_receipt = self._transaction_receipt(transaction_hash)
#     488     except (TransactionNotFound, TransactionIndexingInProgress):
#     489         tx_receipt = None
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/module.py:111, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     104     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     106 (
#     107     result_formatters,
#     108     error_formatters,
#     109     null_result_formatters,
#     110 ) = response_formatters
# --> 111 result = w3.manager.request_blocking(
#     112     method_str, params, error_formatters, null_result_formatters
#     113 )
#     114 return apply_result_formatters(result_formatters, result)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/manager.py:400, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     390 def request_blocking(
#     391     self,
#     392     method: Union[RPCEndpoint, Callable[..., RPCEndpoint]],
#    (...)
#     395     null_result_formatters: Optional[Callable[..., Any]] = None,
#     396 ) -> Any:
#     397     """
#     398     Make a synchronous request using the provider
#     399     """
# --> 400     response = self._make_request(method, params)
#     401     return self.formatted_response(
#     402         response, params, error_formatters, null_result_formatters
#     403     )
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/manager.py:332, in RequestManager._make_request(self, method, params)
#     328 request_func = provider.request_func(
#     329     cast("Web3", self.w3), cast("MiddlewareOnion", self.middleware_onion)
#     330 )
#     331 self.logger.debug(f"Making request. Method: {method}")
# --> 332 return request_func(method, params)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
#     [... skipping similar frames: Web3Middleware.wrap_make_request.<locals>.middleware at line 56 (2 times)]
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/middleware/base.py:56, in Web3Middleware.wrap_make_request.<locals>.middleware(method, params)
#      54 def middleware(method: "RPCEndpoint", params: Any) -> "RPCResponse":
#      55     method, params = self.request_processor(method, params)
# ---> 56     return self.response_processor(method, make_request(method, params))
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/_utils/caching/caching_utils.py:259, in handle_request_caching.<locals>.wrapper(provider, method, params)
#     257         return response
#     258 else:
# --> 259     return func(provider, method, params)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/providers/rpc/rpc.py:170, in HTTPProvider.make_request(self, method, params)
#     166 self.logger.debug(
#     167     f"Making request HTTP. URI: {self.endpoint_uri}, Method: {method}"
#     168 )
#     169 request_data = self.encode_rpc_request(method, params)
# --> 170 raw_response = self._make_request(method, request_data)
#     171 response = self.decode_rpc_response(raw_response)
#     172 self.logger.debug(
#     173     f"Getting response HTTP. URI: {self.endpoint_uri}, "
#     174     f"Method: {method}, Response: {response}"
#     175 )
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/providers/rpc/rpc.py:147, in HTTPProvider._make_request(self, method, request_data)
#     145 for i in range(self.exception_retry_configuration.retries):
#     146     try:
# --> 147         return self._request_session_manager.make_post_request(
#     148             self.endpoint_uri, request_data, **self.get_request_kwargs()
#     149         )
#     150     except tuple(self.exception_retry_configuration.errors) as e:
#     151         if i < self.exception_retry_configuration.retries - 1:
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/_utils/http_session_manager.py:136, in HTTPSessionManager.make_post_request(self, endpoint_uri, data, **kwargs)
#     133 start = time.time()
#     134 timeout = kwargs["timeout"]
# --> 136 with self.get_response_from_post_request(
#     137     endpoint_uri, data=data, **kwargs
#     138 ) as response:
#     139     response.raise_for_status()
#     140     if kwargs.get("stream"):
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/web3/_utils/http_session_manager.py:125, in HTTPSessionManager.get_response_from_post_request(self, endpoint_uri, *args, **kwargs)
#     119 def get_response_from_post_request(
#     120     self, endpoint_uri: URI, *args: Any, **kwargs: Any
#     121 ) -> requests.Response:
#     122     session = self.cache_and_return_session(
#     123         endpoint_uri, request_timeout=kwargs["timeout"]
#     124     )
# --> 125     return session.post(endpoint_uri, *args, **kwargs)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Workspace/cafecosmos-sdk/.venv/lib/python3.9/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
